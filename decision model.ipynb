# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv(os.path.join('data.csv'))
data.head()
# Out:
#              State         Well Name  Depth (m)  Porosity (%)  \
# 0  New South Wales  BMR Wollongong 1       18.7           4.7
# 1  New South Wales  BMR Wollongong 1       23.1           7.4
# 2  New South Wales  BMR Wollongong 1       27.0           9.9
# 3  New South Wales  BMR Wollongong 1       45.8           4.0
# 4  New South Wales  BMR Wollongong 1       70.8           3.1
#
#    Permeability_h (md)  Permeability_v (md) Lithology (major)  \
# 0                  0.1                  0.1             shale
# 1                  0.1                  0.1         sandstone
# 2                  0.2                  0.2         sandstone
# 3                  0.1                  0.1         siltstone
# 4                  0.1                  0.1         siltstone
#
#   Well Classification  Longitude  Latitude Onshore/Offshore        Decision
# 0      Stratigraphic       150.6   34.9667          Onshore  Non-Acceptable
# 1      Stratigraphic       150.6   34.9667          Onshore  Non-Acceptable
# 2      Stratigraphic       150.6   34.9667          Onshore  Non-Acceptable
# 3      Stratigraphic       150.6   34.9667          Onshore  Non-Acceptable
# 4      Stratigraphic       150.6   34.9667          Onshore  Non-Acceptable

# %%
data.describe(include='all')
# Out:
#                       State        Well Name    Depth (m)  Porosity (%)  \
# count                   714              714   714.000000    714.000000
# unique                    8               24          NaN           NaN
# top     Northern Territory   East Mereenie 1          NaN           NaN
# freq                    144              100          NaN           NaN
# mean                    NaN              NaN  1753.248739     13.464426
# std                     NaN              NaN   926.321510      7.680738
# min                     NaN              NaN    18.700000      0.000000
# 25%                     NaN              NaN   976.050000      7.500000
# 50%                     NaN              NaN  1713.050000     11.650000
# 75%                     NaN              NaN  2666.450000     19.100000
# max                     NaN              NaN  4396.500000     42.500000
#
#         Permeability_h (md)  Permeability_v (md) Lithology (major)  \
# count            714.000000           714.000000               714
# unique                  NaN                  NaN                11
# top                     NaN                  NaN         sandstone
# freq                    NaN                  NaN               543
# mean             158.193137            93.267927               NaN
# std              575.452352           441.657868               NaN
# min                0.000000             0.000000               NaN
# 25%                0.000000             0.000000               NaN
# 50%                0.850000             0.100000               NaN
# 75%               23.500000             3.000000               NaN
# max             6662.000000          5994.000000               NaN
#
#        Well Classification   Longitude    Latitude Onshore/Offshore  \
# count                  714  714.000000  714.000000              714
# unique                   5         NaN         NaN                2
# top            Exploration         NaN         NaN          Onshore
# freq                   411         NaN         NaN              520
# mean                   NaN  140.601683   28.336971              NaN
# std                    NaN    9.881360    8.065947              NaN
# min                    NaN  115.393900    7.381100              NaN
# 25%                    NaN  133.966700   24.008600              NaN
# 50%                    NaN  142.988300   27.426700              NaN
# 75%                    NaN  148.096900   38.200800              NaN
# max                    NaN  151.207000   39.997500              NaN
#
#               Decision
# count              714
# unique               2
# top     Non-Acceptable
# freq               634
# mean               NaN
# std                NaN
# min                NaN
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max                NaN

# %%
target = data['Decision']
target_names = ['Acceptable', 'Non-Acceptable']

# %%
data = data.drop(columns=['State', 'Well Name', 'Depth (m)', 'Permeability_v (md)', 'Lithology (major)',
                          'Well Classification', 'Longitude', 'Latitude', 'Onshore/Offshore'])
data.head()
# Out:
#    Porosity (%)  Permeability_h (md)        Decision
# 0           4.7                  0.1  Non-Acceptable
# 1           7.4                  0.1  Non-Acceptable
# 2           9.9                  0.2  Non-Acceptable
# 3           4.0                  0.1  Non-Acceptable
# 4           3.1                  0.1  Non-Acceptable

# %%
data = data.drop('Decision', axis=1)
feature_names = data.columns
data.head()
# Out:
#    Porosity (%)  Permeability_h (md)
# 0           4.7                  0.1
# 1           7.4                  0.1
# 2           9.9                  0.2
# 3           4.0                  0.1
# 4           3.1                  0.1

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
train_scores = []
test_scores = []
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train, y_train)
train_score = knn.score(X_train, y_train)
test_score = knn.score(X_test, y_test)
train_scores.append(train_score)
test_scores.append(test_score)
print(f'k: {knn}, Train/Test Score: {train_score:.3f}/{test_score:.3f}')
# Out:
# k: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#            weights='uniform'), Train/Test Score: 0.951/0.939

# %%
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# C:\Users\kundyz-pc\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
new_data = np.array([[0, 0], [10, 100], [50, 500]])

# %%
print(f'Training Data Score: {classifier.score(X_train, y_train)}')
print(f'Testing Data Score: {classifier.score(X_test, y_test)}')
# Out:
# Training Data Score: 0.930841121495327
# Testing Data Score: 0.8994413407821229

# %%
predictions = classifier.predict(new_data)
print('Classes are either 0 (Acceptable) or 1 (Non-Acceptable)')
print(f'The new points were classified as: {predictions}')
# Out:
# Classes are either 0 (Acceptable) or 1 (Non-Acceptable)
# The new points were classified as: ['Non-Acceptable' 'Non-Acceptable' 'Acceptable']

# %%
predictions = classifier.predict(X_test)
predictions = pd.DataFrame({'Prediction': predictions, 'Actual': y_test})
predictions.head()
# Out:
#          Prediction          Actual
# 120  Non-Acceptable  Non-Acceptable
# 329  Non-Acceptable  Non-Acceptable
# 39   Non-Acceptable      Acceptable
# 294  Non-Acceptable  Non-Acceptable
# 654  Non-Acceptable      Acceptable
